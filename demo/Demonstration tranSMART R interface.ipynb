# %% [markdown]
# # Installation

# %%
install.packages(pkgs=c("RCurl", "rjson", "RProtoBuf", "plyr", "hash", "reshape"))
# Out:
# Installing packages into ‘/usr/local/lib/R/3.3/site-library’
# (as ‘lib’ is unspecified)

# %%
pathOfPackageSource <- "~/tools/RInterface"
install.packages(pathOfPackageSource, repos = NULL, type = "source")
# Out:
# Installing package into ‘/usr/local/lib/R/3.3/site-library’
# (as ‘lib’ is unspecified)

# %%
library("transmartRClient")
# Out:
# Loading required package: httr
# Loading required package: rjson
# Loading required package: plyr
# Loading required package: RProtoBuf
# Loading required package: hash
# hash-2.2.6 provided by Decision Patterns
#
#
# Attaching package: ‘hash’
#
# The following object is masked from ‘package:RProtoBuf’:
#
#     clear
#
# Loading required package: reshape
#
# Attaching package: ‘reshape’
#
# The following objects are masked from ‘package:plyr’:
#
#     rename, round_any

# %% [markdown]
# # Connecting to the server
#
# Go to http://postgres-test.transmartfoundation.org/transmart/oauth/authorize?response_type=code&client_id=api-client&client_secret=api-client&redirect_uri=http%3A%2F%2Fpostgres-test.transmartfoundation.org%2Ftransmart%2Foauth%2Fverify and login with admin/admin

# %%
connectToTransmart("http://postgres-test.transmartfoundation.org/transmart")
# Out:
# Connection active

# %% [markdown]
# # Retrieving all studies in the server

# %%
studies <- getStudies()
studies
# Out:
#                           id
# GSE10024_ETRIKS           GSE10024_ETRIKS
# GSE1456                   GSE1456
# GSE27831                  GSE27831
# GSE10500_ETRIKS           GSE10500_ETRIKS
# GSE13168                  GSE13168
# TEST_GSE37424             TEST_GSE37424
# GSE4271                   GSE4271
# GSE4382                   GSE4382
# GSE23611_ETRIKS           GSE23611_ETRIKS
# GSE11903                  GSE11903
# GSE31773                  GSE31773
# GSE20690                  GSE20690
# COMPLETEGENOMICS          COMPLETEGENOMICS
# GSE34466                  GSE34466
# GSE5327                   GSE5327
# GSE19976                  GSE19976
# TEST_GSE37425             TEST_GSE37425
# GSE4922                   GSE4922
# GSE4698                   GSE4698
# GSE8581                   GSE8581
# GSE38642                  GSE38642
# TEST_GSE42468             TEST_GSE42468
# TEST_WITTEN_2010          TEST_WITTEN_2010
# TEST_MASS_SPEC_PROTEOMICS TEST_MASS_SPEC_PROTEOMICS
# TEST_GSE48213             TEST_GSE48213
# TEST_GSE4382_INC          TEST_GSE4382_INC
# CELL-LINE                 CELL-LINE
# TEST_METABOLOMICS         TEST_METABOLOMICS
# TEST_MANNHEIM             TEST_MANNHEIM
# TEST_GSE49520             TEST_GSE49520
# TEST_RBM_ADNI             TEST_RBM_ADNI
# TEST_GSE18938             TEST_GSE18938
# TEST_SERIAL_RICERCA       TEST_SERIAL_RICERCA
# ACGHTEST                  ACGHTEST
# HAPMAP                    HAPMAP
#                           api.link.self.href
# GSE10024_ETRIKS           /studies/gse10024_etriks
# GSE1456                   /studies/gse1456
# GSE27831                  /studies/gse27831
# GSE10500_ETRIKS           /studies/gse10500_etriks
# GSE13168                  /studies/gse13168
# TEST_GSE37424             /studies/test_gse37424
# GSE4271                   /studies/gse4271
# GSE4382                   /studies/gse4382
# GSE23611_ETRIKS           /studies/gse23611_etriks
# GSE11903                  /studies/gse11903
# GSE31773                  /studies/gse31773
# GSE20690                  /studies/gse20690
# COMPLETEGENOMICS          /studies/completegenomics
# GSE34466                  /studies/gse34466
# GSE5327                   /studies/gse5327
# GSE19976                  /studies/gse19976
# TEST_GSE37425             /studies/test_gse37425
# GSE4922                   /studies/gse4922
# GSE4698                   /studies/gse4698
# GSE8581                   /studies/gse8581
# GSE38642                  /studies/gse38642
# TEST_GSE42468             /studies/test_gse42468
# TEST_WITTEN_2010          /studies/test_witten_2010
# TEST_MASS_SPEC_PROTEOMICS /studies/test_mass_spec_proteomics
# TEST_GSE48213             /studies/test_gse48213
# TEST_GSE4382_INC          /studies/test_gse4382_inc
# CELL-LINE                 /studies/cell-line
# TEST_METABOLOMICS         /studies/test_metabolomics
# TEST_MANNHEIM             /studies/test_mannheim
# TEST_GSE49520             /studies/test_gse49520
# TEST_RBM_ADNI             /studies/test_rbm_adni
# TEST_GSE18938             /studies/test_gse18938
# TEST_SERIAL_RICERCA       /studies/test_serial_ricerca
# ACGHTEST                  /studies/acghtest
# HAPMAP                    /studies/hapmap
#                           ontologyTerm.fullName
# GSE10024_ETRIKS           \\eTRIKS Rheumatoid Arthritis\\Andreas(2008) GSE10024\\
# GSE1456                   \\Public Studies\\Breast Cancer_Pawitan_GSE1456\\
# GSE27831                  \\Public Studies\\Melanoma Uveal_Gangemi_GSE27831\\
# GSE10500_ETRIKS           \\eTRIKS Rheumatoid Arthritis\\Yarilina(2008) GSE10500\\
# GSE13168                  \\Public Studies\\Asthma_Misior_GSE13168\\
# TEST_GSE37424             \\Test Studies\\test_qPCR_miRNA_GSE37424\\
# GSE4271                   \\Public Studies\\Brain Cancer_Phillips_GSE4271\\
# GSE4382                   \\Public Studies\\Breast Cancer_Sorlie_GSE4382\\
# GSE23611_ETRIKS           \\eTRIKS Asthma\\Choy(2011) GSE23611\\
# GSE11903                  \\Public Studies\\Psoriasis_Zaba_GSE11903\\
# GSE31773                  \\Public Studies\\Asthma_Tsitsiou_GSE31773\\
# GSE20690                  \\Public Studies\\Rheumatoid Arthritis_Takeuchi_GSE20690\\
# COMPLETEGENOMICS          \\Public Studies\\Complete Genomics_Breast Cancer Blood Pair\\
# GSE34466                  \\Public Studies\\Asthma_Barczak_GSE34466\\
# GSE5327                   \\Public Studies\\Breast Cancer_Minn_GSE5327\\
# GSE19976                  \\Public Studies\\Pulmonary Sarcoidosis_Ho_GSE19976\\
# TEST_GSE37425             \\Test Studies\\test_qPCR_miRNA_GSE37425\\
# GSE4922                   \\Public Studies\\Breast Cancer_Ivshina_GSE4922\\
# GSE4698                   \\Public Studies\\Acute Lymphoblastic Leukemia_Kirschner_Schwabe_GSE4698\\
# GSE8581                   \\Public Studies\\COPD_Bhattacharya_GSE8581\\
# GSE38642                  \\Public Studies\\Type 2 Diabetes Taneera GSE38642\\
# TEST_GSE42468             \\Test Studies\\test_qPCR_miRNA_GSE42468\\
# TEST_WITTEN_2010          \\Test Studies\\test_miRNAseq_Witten_et_al_2010\\
# TEST_MASS_SPEC_PROTEOMICS \\Test Studies\\test_mass_spec_proteomics\\
# TEST_GSE48213             \\Test Studies\\test_RNAseq_GSE48213\\
# TEST_GSE4382_INC          \\Test Studies\\test_GSE4382_incremental\\
# CELL-LINE                 \\Private Studies\\Cell-line\\
# TEST_METABOLOMICS         \\Test Studies\\test_metabolomics\\
# TEST_MANNHEIM             \\Test Studies\\test_mannheim_with_samples\\
# TEST_GSE49520             \\Test Studies\\test_qPCR_miRNA_GSE49520\\
# TEST_RBM_ADNI             \\Test Studies\\test_rbm_adni\\
# TEST_GSE18938             \\Test Studies\\test_serial_high_dim\\
# TEST_SERIAL_RICERCA       \\Test Studies\\test_serial_high_dim_ricerca\\
# ACGHTEST                  \\Public Studies\\Test aCGH Copy Number Variations\\
# HAPMAP                    \\Public Studies\\HAPMAP\\

# %% [markdown]
# # Retrieving all variables for a study

# %%
study <- "GSE8581"
concepts <- getConcepts(study)
concepts
# Out:
#    name
# 1  Affymetrix Human Genome U133 Plus 2.0 Array
# 2  Afro American
# 3  Age
# 4  Biomarker Data
# 5  carcinoid
# 6  Caucasian
# 7  chronic obstructive pulmonary disease
# 8  control
# 9  Diagnosis
# 10 emphysema
# 11 Endpoints
# 12 female
# 13 FEV1
# 14 Forced Expiratory Volume Ratio
# 15 giant bullae
# 16 Giant Cell Tumor
# 17 Height (inch)
# 18 hematoma
# 19 Homo sapiens
# 20 inflammation
# 21 Lung
# 22 Lung Disease
# 23 lymphoma
# 24 male
# 25 metastatic non-small cell adenocarcinoma
# 26 metastatic renal cell carcinoma
# 27 no malignancy
# 28 non-small cell adenocarcinoma
# 29 non-small cell squamous cell carcinoma
# 30 not specified
# 31 NSC-Mixed
# 32 Organism
# 33 Race
# 34 Sex
# 35 Subjects
# 36 Unknown
#    fullName
# 1  \\Public Studies\\COPD_Bhattacharya_GSE8581\\Biomarker Data\\Affymetrix Human Genome U133 Plus 2.0 Array\\
# 2  \\Public Studies\\COPD_Bhattacharya_GSE8581\\Subjects\\Race\\Afro American\\
# 3  \\Public Studies\\COPD_Bhattacharya_GSE8581\\Subjects\\Age\\
# 4  \\Public Studies\\COPD_Bhattacharya_GSE8581\\Biomarker Data\\
# 5  \\Public Studies\\COPD_Bhattacharya_GSE8581\\Endpoints\\Diagnosis\\carcinoid\\
# 6  \\Public Studies\\COPD_Bhattacharya_GSE8581\\Subjects\\Race\\Caucasian\\
# 7  \\Public Studies\\COPD_Bhattacharya_GSE8581\\Subjects\\Lung Disease\\chronic obstructive pulmonary disease\\
# 8  \\Public Studies\\COPD_Bhattacharya_GSE8581\\Subjects\\Lung Disease\\control\\
# 9  \\Public Studies\\COPD_Bhattacharya_GSE8581\\Endpoints\\Diagnosis\\
# 10 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Endpoints\\Diagnosis\\emphysema\\
# 11 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Endpoints\\
# 12 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Subjects\\Sex\\female\\
# 13 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Endpoints\\FEV1\\
# 14 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Endpoints\\Forced Expiratory Volume Ratio\\
# 15 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Endpoints\\Diagnosis\\giant bullae\\
# 16 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Endpoints\\Diagnosis\\Giant Cell Tumor\\
# 17 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Subjects\\Height (inch)\\
# 18 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Endpoints\\Diagnosis\\hematoma\\
# 19 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Subjects\\Organism\\Homo sapiens\\
# 20 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Endpoints\\Diagnosis\\inflammation\\
# 21 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Biomarker Data\\Affymetrix Human Genome U133 Plus 2.0 Array\\Lung\\
# 22 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Subjects\\Lung Disease\\
# 23 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Endpoints\\Diagnosis\\lymphoma\\
# 24 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Subjects\\Sex\\male\\
# 25 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Endpoints\\Diagnosis\\metastatic non-small cell adenocarcinoma\\
# 26 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Endpoints\\Diagnosis\\metastatic renal cell carcinoma\\
# 27 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Endpoints\\Diagnosis\\no malignancy\\
# 28 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Endpoints\\Diagnosis\\non-small cell adenocarcinoma\\
# 29 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Endpoints\\Diagnosis\\non-small cell squamous cell carcinoma\\
# 30 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Subjects\\Lung Disease\\not specified\\
# 31 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Endpoints\\Diagnosis\\NSC-Mixed\\
# 32 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Subjects\\Organism\\
# 33 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Subjects\\Race\\
# 34 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Subjects\\Sex\\
# 35 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Subjects\\
# 36 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Endpoints\\Diagnosis\\Unknown\\
#    type
# 1  UNKNOWN
# 2  CATEGORICAL_OPTION
# 3  NUMERIC
# 4  UNKNOWN
# 5  CATEGORICAL_OPTION
# 6  CATEGORICAL_OPTION
# 7  CATEGORICAL_OPTION
# 8  CATEGORICAL_OPTION
# 9  UNKNOWN
# 10 CATEGORICAL_OPTION
# 11 UNKNOWN
# 12 CATEGORICAL_OPTION
# 13 NUMERIC
# 14 NUMERIC
# 15 CATEGORICAL_OPTION
# 16 CATEGORICAL_OPTION
# 17 NUMERIC
# 18 CATEGORICAL_OPTION
# 19 CATEGORICAL_OPTION
# 20 CATEGORICAL_OPTION
# 21 HIGH_DIMENSIONAL
# 22 UNKNOWN
# 23 CATEGORICAL_OPTION
# 24 CATEGORICAL_OPTION
# 25 CATEGORICAL_OPTION
# 26 CATEGORICAL_OPTION
# 27 CATEGORICAL_OPTION
# 28 CATEGORICAL_OPTION
# 29 CATEGORICAL_OPTION
# 30 CATEGORICAL_OPTION
# 31 CATEGORICAL_OPTION
# 32 UNKNOWN
# 33 UNKNOWN
# 34 UNKNOWN
# 35 UNKNOWN
# 36 CATEGORICAL_OPTION
#    api.link.self.href
# 1  /studies/gse8581/concepts/Biomarker%20Data/Affymetrix%20Human%20Genome%20U133%20Plus%202.0%20Array
# 2  /studies/gse8581/concepts/Subjects/Race/Afro%20American
# 3  /studies/gse8581/concepts/Subjects/Age
# 4  /studies/gse8581/concepts/Biomarker%20Data
# 5  /studies/gse8581/concepts/Endpoints/Diagnosis/carcinoid
# 6  /studies/gse8581/concepts/Subjects/Race/Caucasian
# 7  /studies/gse8581/concepts/Subjects/Lung%20Disease/chronic%20obstructive%20pulmonary%20disease
# 8  /studies/gse8581/concepts/Subjects/Lung%20Disease/control
# 9  /studies/gse8581/concepts/Endpoints/Diagnosis
# 10 /studies/gse8581/concepts/Endpoints/Diagnosis/emphysema
# 11 /studies/gse8581/concepts/Endpoints
# 12 /studies/gse8581/concepts/Subjects/Sex/female
# 13 /studies/gse8581/concepts/Endpoints/FEV1
# 14 /studies/gse8581/concepts/Endpoints/Forced%20Expiratory%20Volume%20Ratio
# 15 /studies/gse8581/concepts/Endpoints/Diagnosis/giant%20bullae
# 16 /studies/gse8581/concepts/Endpoints/Diagnosis/Giant%20Cell%20Tumor
# 17 /studies/gse8581/concepts/Subjects/Height%20%28inch%29
# 18 /studies/gse8581/concepts/Endpoints/Diagnosis/hematoma
# 19 /studies/gse8581/concepts/Subjects/Organism/Homo%20sapiens
# 20 /studies/gse8581/concepts/Endpoints/Diagnosis/inflammation
# 21 /studies/gse8581/concepts/Biomarker%20Data/Affymetrix%20Human%20Genome%20U133%20Plus%202.0%20Array/Lung
# 22 /studies/gse8581/concepts/Subjects/Lung%20Disease
# 23 /studies/gse8581/concepts/Endpoints/Diagnosis/lymphoma
# 24 /studies/gse8581/concepts/Subjects/Sex/male
# 25 /studies/gse8581/concepts/Endpoints/Diagnosis/metastatic%20non-small%20cell%20adenocarcinoma
# 26 /studies/gse8581/concepts/Endpoints/Diagnosis/metastatic%20renal%20cell%20carcinoma
# 27 /studies/gse8581/concepts/Endpoints/Diagnosis/no%20malignancy
# 28 /studies/gse8581/concepts/Endpoints/Diagnosis/non-small%20cell%20adenocarcinoma
# 29 /studies/gse8581/concepts/Endpoints/Diagnosis/non-small%20cell%20squamous%20cell%20carcinoma
# 30 /studies/gse8581/concepts/Subjects/Lung%20Disease/not%20specified
# 31 /studies/gse8581/concepts/Endpoints/Diagnosis/NSC-Mixed
# 32 /studies/gse8581/concepts/Subjects/Organism
# 33 /studies/gse8581/concepts/Subjects/Race
# 34 /studies/gse8581/concepts/Subjects/Sex
# 35 /studies/gse8581/concepts/Subjects
# 36 /studies/gse8581/concepts/Endpoints/Diagnosis/Unknown
#    api.link.observations.href
# 1  /studies/gse8581/concepts/Biomarker%20Data/Affymetrix%20Human%20Genome%20U133%20Plus%202.0%20Array/observations
# 2  /studies/gse8581/concepts/Subjects/Race/Afro%20American/observations
# 3  /studies/gse8581/concepts/Subjects/Age/observations
# 4  /studies/gse8581/concepts/Biomarker%20Data/observations
# 5  /studies/gse8581/concepts/Endpoints/Diagnosis/carcinoid/observations
# 6  /studies/gse8581/concepts/Subjects/Race/Caucasian/observations
# 7  /studies/gse8581/concepts/Subjects/Lung%20Disease/chronic%20obstructive%20pulmonary%20disease/observations
# 8  /studies/gse8581/concepts/Subjects/Lung%20Disease/control/observations
# 9  /studies/gse8581/concepts/Endpoints/Diagnosis/observations
# 10 /studies/gse8581/concepts/Endpoints/Diagnosis/emphysema/observations
# 11 /studies/gse8581/concepts/Endpoints/observations
# 12 /studies/gse8581/concepts/Subjects/Sex/female/observations
# 13 /studies/gse8581/concepts/Endpoints/FEV1/observations
# 14 /studies/gse8581/concepts/Endpoints/Forced%20Expiratory%20Volume%20Ratio/observations
# 15 /studies/gse8581/concepts/Endpoints/Diagnosis/giant%20bullae/observations
# 16 /studies/gse8581/concepts/Endpoints/Diagnosis/Giant%20Cell%20Tumor/observations
# 17 /studies/gse8581/concepts/Subjects/Height%20%28inch%29/observations
# 18 /studies/gse8581/concepts/Endpoints/Diagnosis/hematoma/observations
# 19 /studies/gse8581/concepts/Subjects/Organism/Homo%20sapiens/observations
# 20 /studies/gse8581/concepts/Endpoints/Diagnosis/inflammation/observations
# 21 NA
# 22 /studies/gse8581/concepts/Subjects/Lung%20Disease/observations
# 23 /studies/gse8581/concepts/Endpoints/Diagnosis/lymphoma/observations
# 24 /studies/gse8581/concepts/Subjects/Sex/male/observations
# 25 /studies/gse8581/concepts/Endpoints/Diagnosis/metastatic%20non-small%20cell%20adenocarcinoma/observations
# 26 /studies/gse8581/concepts/Endpoints/Diagnosis/metastatic%20renal%20cell%20carcinoma/observations
# 27 /studies/gse8581/concepts/Endpoints/Diagnosis/no%20malignancy/observations
# 28 /studies/gse8581/concepts/Endpoints/Diagnosis/non-small%20cell%20adenocarcinoma/observations
# 29 /studies/gse8581/concepts/Endpoints/Diagnosis/non-small%20cell%20squamous%20cell%20carcinoma/observations
# 30 /studies/gse8581/concepts/Subjects/Lung%20Disease/not%20specified/observations
# 31 /studies/gse8581/concepts/Endpoints/Diagnosis/NSC-Mixed/observations
# 32 /studies/gse8581/concepts/Subjects/Organism/observations
# 33 /studies/gse8581/concepts/Subjects/Race/observations
# 34 /studies/gse8581/concepts/Subjects/Sex/observations
# 35 /studies/gse8581/concepts/Subjects/observations
# 36 /studies/gse8581/concepts/Endpoints/Diagnosis/Unknown/observations
#    api.link.children.NA.href
# 1  /studies/gse8581/concepts/Biomarker%20Data/Affymetrix%20Human%20Genome%20U133%20Plus%202.0%20Array/Lung
# 2  NA
# 3  NA
# 4  /studies/gse8581/concepts/Biomarker%20Data/Affymetrix%20Human%20Genome%20U133%20Plus%202.0%20Array
# 5  NA
# 6  NA
# 7  NA
# 8  NA
# 9  /studies/gse8581/concepts/Endpoints/Diagnosis/Unknown
# 10 NA
# 11 /studies/gse8581/concepts/Endpoints/Forced%20Expiratory%20Volume%20Ratio
# 12 NA
# 13 NA
# 14 NA
# 15 NA
# 16 NA
# 17 NA
# 18 NA
# 19 NA
# 20 NA
# 21 NA
# 22 /studies/gse8581/concepts/Subjects/Lung%20Disease/not%20specified
# 23 NA
# 24 NA
# 25 NA
# 26 NA
# 27 NA
# 28 NA
# 29 NA
# 30 NA
# 31 NA
# 32 /studies/gse8581/concepts/Subjects/Organism/Homo%20sapiens
# 33 /studies/gse8581/concepts/Subjects/Race/Caucasian
# 34 /studies/gse8581/concepts/Subjects/Sex/male
# 35 /studies/gse8581/concepts/Subjects/Sex
# 36 NA
#    api.link.children.NA.title
# 1  Lung
# 2  NA
# 3  NA
# 4  Affymetrix Human Genome U133 Plus 2.0 Array
# 5  NA
# 6  NA
# 7  NA
# 8  NA
# 9  Unknown
# 10 NA
# 11 Forced Expiratory Volume Ratio
# 12 NA
# 13 NA
# 14 NA
# 15 NA
# 16 NA
# 17 NA
# 18 NA
# 19 NA
# 20 NA
# 21 NA
# 22 not specified
# 23 NA
# 24 NA
# 25 NA
# 26 NA
# 27 NA
# 28 NA
# 29 NA
# 30 NA
# 31 NA
# 32 Homo sapiens
# 33 Caucasian
# 34 male
# 35 Sex
# 36 NA
#    api.link.parent.href
# 1  /studies/gse8581/concepts/Biomarker%20Data
# 2  /studies/gse8581/concepts/Subjects/Race
# 3  /studies/gse8581/concepts/Subjects
# 4  /studies/gse8581/concepts/ROOT
# 5  /studies/gse8581/concepts/Endpoints/Diagnosis
# 6  /studies/gse8581/concepts/Subjects/Race
# 7  /studies/gse8581/concepts/Subjects/Lung%20Disease
# 8  /studies/gse8581/concepts/Subjects/Lung%20Disease
# 9  /studies/gse8581/concepts/Endpoints
# 10 /studies/gse8581/concepts/Endpoints/Diagnosis
# 11 /studies/gse8581/concepts/ROOT
# 12 /studies/gse8581/concepts/Subjects/Sex
# 13 /studies/gse8581/concepts/Endpoints
# 14 /studies/gse8581/concepts/Endpoints
# 15 /studies/gse8581/concepts/Endpoints/Diagnosis
# 16 /studies/gse8581/concepts/Endpoints/Diagnosis
# 17 /studies/gse8581/concepts/Subjects
# 18 /studies/gse8581/concepts/Endpoints/Diagnosis
# 19 /studies/gse8581/concepts/Subjects/Organism
# 20 /studies/gse8581/concepts/Endpoints/Diagnosis
# 21 /studies/gse8581/concepts/Biomarker%20Data/Affymetrix%20Human%20Genome%20U133%20Plus%202.0%20Array
# 22 /studies/gse8581/concepts/Subjects
# 23 /studies/gse8581/concepts/Endpoints/Diagnosis
# 24 /studies/gse8581/concepts/Subjects/Sex
# 25 /studies/gse8581/concepts/Endpoints/Diagnosis
# 26 /studies/gse8581/concepts/Endpoints/Diagnosis
# 27 /studies/gse8581/concepts/Endpoints/Diagnosis
# 28 /studies/gse8581/concepts/Endpoints/Diagnosis
# 29 /studies/gse8581/concepts/Endpoints/Diagnosis
# 30 /studies/gse8581/concepts/Subjects/Lung%20Disease
# 31 /studies/gse8581/concepts/Endpoints/Diagnosis
# 32 /studies/gse8581/concepts/Subjects
# 33 /studies/gse8581/concepts/Subjects
# 34 /studies/gse8581/concepts/Subjects
# 35 /studies/gse8581/concepts/ROOT
# 36 /studies/gse8581/concepts/Endpoints/Diagnosis
#    api.link.highdim.href
# 1  NA
# 2  NA
# 3  NA
# 4  NA
# 5  NA
# 6  NA
# 7  NA
# 8  NA
# 9  NA
# 10 NA
# 11 NA
# 12 NA
# 13 NA
# 14 NA
# 15 NA
# 16 NA
# 17 NA
# 18 NA
# 19 NA
# 20 NA
# 21 /studies/gse8581/concepts/Biomarker%20Data/Affymetrix%20Human%20Genome%20U133%20Plus%202.0%20Array/Lung/highdim
# 22 NA
# 23 NA
# 24 NA
# 25 NA
# 26 NA
# 27 NA
# 28 NA
# 29 NA
# 30 NA
# 31 NA
# 32 NA
# 33 NA
# 34 NA
# 35 NA
# 36 NA

# %% [markdown]
# # Retrieving clinical data

# %%
# Retrieve Clinical Data
allObservations <- getObservations(study, as.data.frame = T)

#the clinical data is stored in three tables: 
# - an observation table with the clinical measurements
# - a subjectInfo table which contains information about the subjects/patients, such as their age or sex
# - and a table with information about the variables/concepts and where they can be 
#    found in the data tree  of tranSMART (see the panel "Navigate terms" in the "Analyze" tab of the 
#    tranSMART web app: http://transmart-demo.thehyve.net/transmart/datasetExplorer/index ) 
summary(allObservations)
allObservations[[1]][1:12,1:7] #hint: if you are using RStudio you can also use the function "View" to see the data in a more user-friendly table, e.g.: View(allObservations[[1]])
allObservations[[2]][1:12,]
allObservations[[3]][1:10,]
# Out:
#              Length Class      Mode
# observations 11     cast_df    list
# subjectInfo   7     data.frame list
# conceptInfo   2     data.frame list
#    subject.id Biomarker Data_Affymetrix Human Genome U133 Plus 2.0 Array
# 1  1213       E
# 2  1214       E
# 3  1215       E
# 4  1216       E
# 5  1217       E
# 6  1218       E
# 7  1219       E
# 8  1220       E
# 9  1221       E
# 10 1222       E
# 11 1223       E
# 12 1224       E
#    Endpoints_Diagnosis                    Endpoints_FEV1
# 1  non-small cell adenocarcinoma          1.41
# 2  non-small cell squamous cell carcinoma 1.29
# 3  inflammation                           4.04
# 4  non-small cell squamous cell carcinoma 2.06
# 5  non-small cell squamous cell carcinoma 2.25
# 6  giant bullae                           0.4
# 7  non-small cell adenocarcinoma          2.76
# 8  non-small cell adenocarcinoma          2.59
# 9  non-small cell adenocarcinoma          1.45
# 10 non-small cell squamous cell carcinoma 0.9
# 11 Giant Cell Tumor                       0.99
# 12 non-small cell adenocarcinoma          1.7
#    Endpoints_Forced Expiratory Volume Ratio Subjects_Age Subjects_Height (inch)
# 1  51                                       65           66
# 2  53                                       77           67
# 3  79                                       55           69
# 4  54                                       64           65
# 5  72                                       77           66
# 6  45                                       61           73
# 7  70.58                                    61           69
# 8  74                                       68           65
# 9  73                                       77           63
# 10 55.9                                     70           71
# 11 63                                       72           60
# 12 72                                       71           71
#     subject.id subject.race  subject.age subject.trial subject.inTrialId
# 1   1213       Afro American 65          GSE8581       GSE8581GSM210006
# 11  1214       Caucasian     77          GSE8581       GSE8581GSM212788
# 21  1215       Caucasian     55          GSE8581       GSE8581GSM212067
# 31  1216       Caucasian     64          GSE8581       GSE8581GSM212074
# 41  1217       Caucasian     77          GSE8581       GSE8581GSM213037
# 51  1218       Caucasian     61          GSE8581       GSE8581GSM210993
# 61  1219       Caucasian     61          GSE8581       GSE8581GSM210012
# 71  1220       Caucasian     68          GSE8581       GSE8581GSM210087
# 81  1221       Caucasian     77          GSE8581       GSE8581GSM210010
# 91  1222       Caucasian     70          GSE8581       GSE8581GSM210992
# 101 1223       Caucasian     72          GSE8581       GSE8581GSM212852
# 111 1224       Caucasian     71          GSE8581       GSE8581GSM213019
#     subject.sex subject.api.link.self.href
# 1   FEMALE      /studies/gse8581/subjects/1213
# 11  FEMALE      /studies/gse8581/subjects/1214
# 21  MALE        /studies/gse8581/subjects/1215
# 31  MALE        /studies/gse8581/subjects/1216
# 41  MALE        /studies/gse8581/subjects/1217
# 51  MALE        /studies/gse8581/subjects/1218
# 61  MALE        /studies/gse8581/subjects/1219
# 71  FEMALE      /studies/gse8581/subjects/1220
# 81  FEMALE      /studies/gse8581/subjects/1221
# 91  MALE        /studies/gse8581/subjects/1222
# 101 FEMALE      /studies/gse8581/subjects/1223
# 111 FEMALE      /studies/gse8581/subjects/1224
#    conceptNames
# 1  Biomarker Data_Affymetrix Human Genome U133 Plus 2.0 Array
# 2  Endpoints_Diagnosis
# 3  Endpoints_FEV1
# 4  Endpoints_Forced Expiratory Volume Ratio
# 5  Subjects_Age
# 6  Subjects_Height (inch)
# 7  Subjects_Lung Disease
# 8  Subjects_Organism
# 9  Subjects_Race
# 10 Subjects_Sex
#    label
# 1  \\Public Studies\\COPD_Bhattacharya_GSE8581\\Biomarker Data\\Affymetrix Human Genome U133 Plus 2.0 Array\\
# 2  \\Public Studies\\COPD_Bhattacharya_GSE8581\\Endpoints\\Diagnosis\\
# 3  \\Public Studies\\COPD_Bhattacharya_GSE8581\\Endpoints\\FEV1\\
# 4  \\Public Studies\\COPD_Bhattacharya_GSE8581\\Endpoints\\Forced Expiratory Volume Ratio\\
# 5  \\Public Studies\\COPD_Bhattacharya_GSE8581\\Subjects\\Age\\
# 6  \\Public Studies\\COPD_Bhattacharya_GSE8581\\Subjects\\Height (inch)\\
# 7  \\Public Studies\\COPD_Bhattacharya_GSE8581\\Subjects\\Lung Disease\\
# 8  \\Public Studies\\COPD_Bhattacharya_GSE8581\\Subjects\\Organism\\
# 9  \\Public Studies\\COPD_Bhattacharya_GSE8581\\Subjects\\Race\\
# 10 \\Public Studies\\COPD_Bhattacharya_GSE8581\\Subjects\\Sex\\

# %% [markdown]
# # Retrieving gene expression data

# %%
dataDownloaded <- getHighdimData(study.name = "GSE8581", concept.match = "Lung", projection = "log_intensity")
summary(dataDownloaded)
# Out:
# retrieving concepts...
# retrieving highdim info...
# Retrieving data from server. This can take some time, depending on your network connection speed. 2017-04-10 23:59:02
# Retrieving data...
# Downloading: 27 MB
# Download complete.
# Received data for 58 assays. Unpacking data. 2017-04-11 00:00:09
#   |======================================================================| 100%
# Data unpacked. Converting to data.frame. 2017-04-11 00:00:33
# Additional biomarker information is available.
# This function will return a list containing a dataframe containing the high dimensional data and a hash describing which (column) labels refer to which bioMarker
#                     Length Class      Mode
# data                54680  data.frame list
# labelToBioMarkerMap 54674  hash       S4

# %%
#select gene expression data
data<-dataDownloaded[[1]]
data[1:4,1:10]
expression_data<-data[,-c(1:6)]
dim(expression_data)
rownames(expression_data)<-data$patientId

#Make a heatmap
#If the dimensions of the expression_data table are large, you may want to create a subset of the data first. 

# in this case we use the following probelist as a subset for the probes:
# (extracted from 1: "Bhattacharya S., Srisuma S., Demeo D. L., et al.,  Molecular biomarkers for quantitative and discrete COPD phenotypes.
#  American Journal of Respiratory Cell and Molecular Biology. 2009;40(3):359–367. doi: 10.1165/rcmb.2008-0114OC.")
probeNames<- c("1552622_s_at","1555318_at","1557293_at","1558280_s_at","1558411_at","1558515_at","1559964_at","204284_at","205051_s_at","205528_s_at","208835_s_at","209377_s_at","209815_at","211548_s_at","212179_at","212263_at","213156_at","213269_at","213650_at","213878_at","215359_x_at","215933_s_at","218352_at","218490_s_at","220094_s_at","220906_at","220925_at","222108_at","224711_at","225318_at","225595_at","225835_at","225892_at","226316_at","226492_at","226534_at","226666_at","226800_at","227095_at","227105_at","227148_at","227812_at","227852_at","227930_at","227947_at","228157_at","228630_at","228665_at","228760_at","228850_s_at","228875_at","228963_at","229111_at","229572_at","230142_s_at","230986_at","232014_at","235423_at","235810_at","238712_at","238992_at","239842_x_at","239847_at","241936_x_at","242389_at")
probeNames<- paste("X", probeNames, sep = "") #note: R automatically prepends "X" in front of column names that start with a numerical value. Therefore prepend "X"

# select only the cases and controls (excluding the patients for which the lung disease is not specified). Note: in the observation table the database IDs 
# are used to identify the patients and not the patient IDs that are used in the gene expression dataset
cases <- allObservations$observations$subject.id[ allObservations$observations$'Subjects_Lung Disease' == "chronic obstructive pulmonary disease"]
controls <- allObservations$observations$subject.id[allObservations$observations$'Subjects_Lung Disease' == "control"]

# if you are using the Transmart Foundation's instance, you might need to run the following instead:
  #cases <- allObservations$observations$subject.id[!is.na(allObservations$observations$'Subjects_Lung Disease_chronic obstructive pulmonary disease')]
  #controls <- allObservations$observations$subject.id[!is.na(allObservations$observations$'Subjects_Lung Disease_control')]


# now we have the database IDs for the patients, but we need to get the patient IDs. These can be retrieved from the subjectInfo table: 
subjectInfo <- allObservations$subjectInfo
patientIDsCase    <- subjectInfo$subject.inTrialId[ subjectInfo$subject.id %in% cases ] 
patientIDsControl <- subjectInfo$subject.inTrialId[ subjectInfo$subject.id %in% controls] 

patientSet <- c(patientIDsCase,patientIDsControl)

patientSet<-patientSet[which(patientSet %in% rownames(expression_data))]
#make a subset of the data based on the selected patientSet and the probelist, and transpose the table so that the rows now contain probe names
subset<-t(expression_data[patientSet,probeNames]) 

#for ease of recognition: append "Case" and "Control" to the patient names
colnames(subset)[colnames(subset)%in% patientIDsCase] <- paste(colnames(subset)[colnames(subset)%in% patientIDsCase],"Case", sep="_" )
colnames(subset)[colnames(subset)%in% patientIDsControl] <- paste( colnames(subset)[colnames(subset)%in% patientIDsControl] , "Control",sep= "_")

dim(subset)
heatmap(as.matrix(subset), scale = "row")
# Out:
#   assayId patientId        sampleTypeName timepointName tissueTypeName platform
# 1 1261    GSE8581GSM210193 Human                        Lung           GPL570
# 2 1262    GSE8581GSM210007 Human                        Lung           GPL570
# 3 1263    GSE8581GSM210005 Human                        Lung           GPL570
# 4 1264    GSE8581GSM213019 Human                        Lung           GPL570
#   X235956_at X226260_x_at X232632_at X214503_x_at
# 1 6.670685   4.025853     7.538934    0.93891054
# 2 6.104142   3.962614     8.186431    0.06790025
# 3 6.510147   4.170021     7.013395   -1.03971072
# 4 6.969680   5.654816     6.005398   -0.26634717
# [1]    58 54674
# [1] 65 36
# plot without title

# %%
#there is one patient that seems to be an outlier: GSE8581GSM212810_Case
subset_without_outlier <- subset[,colnames(subset)!= "GSE8581GSM212810_Case"]
heatmap(as.matrix(subset_without_outlier), scale = "row")
# Out:
# plot without title
